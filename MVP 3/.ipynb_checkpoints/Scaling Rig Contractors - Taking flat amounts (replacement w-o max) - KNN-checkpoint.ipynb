# %%
# Sampling Rig Contractors - Sampling without max - KNN

Here the thought process is similar to the sampling without replacement, but we understand that amplifying

# %%
from time import time
import numpy as np
import matplotlib.pyplot as plt

from sklearn import metrics
from sklearn.cluster import KMeans
from sklearn.datasets import load_digits
from sklearn.decomposition import PCA
from sklearn.preprocessing import scale

import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split
import os
import torch
from torch import nn
from torch.autograd import Variable
import torch.nn.functional as F

from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

# %%
data_rcompl = pd.read_excel("RCOMPL_KNN_IMPUTED.xlsx")

# %%
unique_rigs = data_rcompl["CONTRACTOR"].unique()

# %%
total_entries = []

for i in unique_rigs:
    temp_pd = data_rcompl[data_rcompl["CONTRACTOR"] == i]
    print(i, " has ", len(temp_pd), " elements.")
    total_entries.append(len(temp_pd))
# Out:
# CONTRACTOR - 2019000027  has  805  elements.
# CONTRACTOR - 2019000030  has  403  elements.
# CONTRACTOR - 2019000023  has  165  elements.
# CONTRACTOR - 2019000008  has  259  elements.
# CONTRACTOR - 2019000051  has  22  elements.

# %%
total_entries
# Out:
# [805, 403, 165, 259, 22]

# %%
sum_rcompl = 0

for i in total_entries:
    sum_rcompl += i

tot_samples = (sum_rcompl-805) // 4

# %%
tot_samples
# Out:
# 212

# %%
new_rcompl = pd.DataFrame(columns = data_rcompl.columns)

for i in range(0, len(unique_rigs)):
    temp_pd = data_rcompl[data_rcompl["CONTRACTOR"] == unique_rigs[i]]
    temp_pd = temp_pd.sample(n = tot_samples, replace = True)
    new_rcompl = new_rcompl.append(temp_pd, ignore_index=True)

# %%
new_rcompl
# Out:
#              UWI UWI_SIDETRACK REPORT_START_DATE_YEAR  FRAC_GRADIENT  \
# 0     2019001117             0                   2017            1.0
# 1     2019000699             0                   2019            1.0
# 2     2019001283             0                   2017            1.0
# 3     2019000633             1                   2018            1.0
# 4     2019001350             0                   2018            1.0
# ...          ...           ...                    ...            ...
# 1055  2019000278             0                   2019            1.0
# 1056  2019000278             0                   2019            1.0
# 1057  2019000278             0                   2019            1.0
# 1058  2019000278             0                   2019            1.0
# 1059  2019000278             0                   2019            1.0
#
#       BREAKDOWN_PRESSURE  HYDROSTATIC_PRESSURE  TREAT_AVG_PRESSURE  \
# 0                 6841.0                5483.0              8645.0
# 1                 7151.0                5531.0              9464.0
# 2                 6906.0                5627.0              6835.0
# 3                 7422.0                4964.0              7426.0
# 4                 8564.0                5891.0              8600.0
# ...                  ...                   ...                 ...
# 1055              5423.0                5122.0              8419.0
# 1056              5560.0                5133.0              8373.0
# 1057              5335.0                5119.2              8561.0
# 1058              5319.0                5119.2              8305.0
# 1059              5335.0                5119.2              8561.0
#
#       TREAT_MAX_PRESSURE  TREAT_MIN_PRESSURE PROPPANT_DESIGNED  ...  \
# 0                 8820.0              6841.0            331250  ...
# 1                 9706.0              7346.0            328750  ...
# 2                 7137.0              6537.6            331750  ...
# 3                 7637.0              7422.0            353000  ...
# 4                 9017.0              2964.0            215900  ...
# ...                  ...                 ...               ...  ...
# 1055              8822.0              7618.0            367500  ...
# 1056              8729.0              7618.0            367500  ...
# 1057              9179.0              7618.0            367500  ...
# 1058              9116.0              7618.0            367500  ...
# 1059              9179.0              7618.0            367500  ...
#
#                    DIVERSION_COMPANY  DIVERSION_METHOD  DELIVERY_MODE  \
# 0     DIVERSION_COMPANY - 2019000024              NONE         Casing
# 1     DIVERSION_COMPANY - 2019000007         Frac Plug         Casing
# 2     DIVERSION_COMPANY - 2019000003  Ball 40  7/8 BIO         Casing
# 3     DIVERSION_COMPANY - 2019000003      SILICA FLOUR         Casing
# 4     DIVERSION_COMPANY - 2019000003          Unibeads         Casing
# ...                              ...               ...            ...
# 1055  DIVERSION_COMPANY - 2019000003         Frac Plug         Casing
# 1056  DIVERSION_COMPANY - 2019000003         Frac Plug         Casing
# 1057  DIVERSION_COMPANY - 2019000003         Frac Plug         Casing
# 1058  DIVERSION_COMPANY - 2019000003         Frac Plug         Casing
# 1059  DIVERSION_COMPANY - 2019000003         Frac Plug         Casing
#
#       BOTTOM_HOLE_PRESSURE_METHOD  CLOSURE_PRESSURE_METHOD  \
# 0                      Calculated         Nolte-Smith Calc
# 1                      Calculated         Nolte-Smith Calc
# 2                      Calculated         Nolte-Smith Calc
# 3                      Calculated         Nolte-Smith Calc
# 4                      Calculated         Nolte-Smith Calc
# ...                           ...                      ...
# 1055                   Calculated         Nolte-Smith Calc
# 1056                   Calculated         Nolte-Smith Calc
# 1057                   Calculated         Nolte-Smith Calc
# 1058                   Calculated         Nolte-Smith Calc
# 1059                   Calculated         Nolte-Smith Calc
#
#       STIMULATION_RESULT  STIMULATION_RESULT_DETAIL  \
# 0                Success               Changed Plan
# 1                Success          According to Plan
# 2                Success          According to Plan
# 3                Success          According to Plan
# 4                Success          According to Plan
# ...                  ...                        ...
# 1055             Success          According to Plan
# 1056             Success          According to Plan
# 1057             Success          According to Plan
# 1058             Success          According to Plan
# 1059             Success          According to Plan
#
#                           STIMTREAT_ID       FLUID_NAME     SITE_SUPERVISOR
# 0     D985AC86468F41CBB1B3C3FFA9D912F2   25# X-LINK GEL        ERIC KILGORE
# 1     BE5448855A8A441F8DEDDDC34C2361B8       Slickwater        JAVIER SOLIS
# 2     1F9DC64FA4274F3EA2DA5079C013E272        XLINK GEL       JAYROE/KRAMER
# 3     73F231E7A06B4C5D88EB8A4F44EB8194   20# X-LINK GEL           JW KRAMER
# 4     312874D310234261BB2728B7C6450FB0  25# Guar Borate  A. VELA/ R. TUCKER
# ...                                ...              ...                 ...
# 1055  75175C188E444E75A22E51B19EF69593       Slickwater       ADEMAR GALVAN
# 1056  83DE70239D7B47A6A4195F0F476A2BAB       Slickwater     EFRAIN GONZALES
# 1057  ACA7734DDC7D4EB9AA4213B6C7AD9FA8       Slickwater    HECTOR RODRIGUEZ
# 1058  01406199182444F5BFEBD3FD820A6589       Slickwater       ADEMAR GALVAN
# 1059  ACA7734DDC7D4EB9AA4213B6C7AD9FA8       Slickwater    HECTOR RODRIGUEZ
#
# [1060 rows x 149 columns]

# %%
new_rcompl.to_excel("RCOMPL_RIG_SCALED_REPLACE_WO_MAX.xlsx")

# %%
data_stmstg = pd.read_excel("STMSTG_KNN_IMPUTED.xlsx")

# %%
unique_rigs = data_stmstg["CONTRACTOR"].unique()

# %%
total_entries = []

for i in unique_rigs:
    temp_pd = data_stmstg[data_stmstg["CONTRACTOR"] == i]
    print(i, " has ", len(temp_pd), " elements.")
    total_entries.append(len(temp_pd))
# Out:
# CONTRACTOR - 2019000008  has  3455  elements.
# CONTRACTOR - 2019000027  has  8790  elements.
# CONTRACTOR - 2019000030  has  3825  elements.
# CONTRACTOR - 2019000023  has  1191  elements.
# CONTRACTOR - 2019000051  has  460  elements.

# %%
total_entries
# Out:
# [3455, 8790, 3825, 1191, 460]

# %%
sum_stmstg = 0

for i in total_entries:
    sum_stmstg += i

print("total sum", sum_stmstg)
tot_samples = (sum_stmstg-8790) // 4
# Out:
# total sum 17721

# %%
tot_samples
# Out:
# 2232

# %%
new_stmstg = pd.DataFrame(columns = data_stmstg.columns)

for i in range(0, len(unique_rigs)):
    temp_pd = data_stmstg[data_stmstg["CONTRACTOR"] == unique_rigs[i]]
    temp_pd = temp_pd.sample(n = tot_samples, replace = True)
    new_stmstg = new_stmstg.append(temp_pd, ignore_index=True)

# %%
new_stmstg
# Out:
#               UWI UWI_SIDETRACK FRAC_GRADIENT  BREAKDOWN_PRESSURE  \
# 0      2019000391             0             1              8392.0
# 1      2019000865             0             1              7450.0
# 2      2019000486             0             1              7050.0
# 3      2019000863             0             1              9275.0
# 4      2019000445             0             1              6503.0
# ...           ...           ...           ...                 ...
# 11155  2019000062             0             1              7063.0
# 11156  2019000060             0             1              8340.0
# 11157  2019000065             0             1              7362.0
# 11158  2019000060             0             1              6737.0
# 11159  2019000060             0             1              7249.0
#
#        HYDROSTATIC_PRESSURE  TREAT_AVG_PRESSURE  TREAT_MAX_PRESSURE  \
# 0                    5493.0             10591.0             11132.0
# 1                    5588.0             10331.0             10786.0
# 2                    5459.0              9532.0             10537.0
# 3                    5413.0             10566.0             10943.0
# 4                    5372.0             10096.0             10851.0
# ...                     ...                 ...                 ...
# 11155                5219.0              9658.0             10353.0
# 11156                5094.0             10256.0             10539.0
# 11157                5134.0             10008.0             10228.0
# 11158                5132.0             10357.0             10499.0
# 11159                5196.0             10212.0             10500.0
#
#        TREAT_MIN_PRESSURE PROPPANT_DESIGNED PROPPANT_IN_FORMATION  ...  \
# 0                  8181.8            520000                520000  ...
# 1                  7488.0            520000                519820  ...
# 2                  6900.0            520000                519600  ...
# 3                  8325.4            520000                520460  ...
# 4                  9525.0            520000                520560  ...
# ...                   ...               ...                   ...  ...
# 11155              7527.8            420000                419000  ...
# 11156              7780.0            420000                420100  ...
# 11157              8846.8            420000                246060  ...
# 11158              7953.4            420000                421640  ...
# 11159              7729.8            420000                431949  ...
#
#                     STIM_TREAT_COMPANY  STIM_TREAT_SUPERVISOR  \
# 0      STIM_TREAT_COMPANY - 2019000002             DAN MORGAN
# 1      STIM_TREAT_COMPANY - 2019000002                  BRIAN
# 2      STIM_TREAT_COMPANY - 2019000002                 GABINO
# 3      STIM_TREAT_COMPANY - 2019000002                     BO
# 4      STIM_TREAT_COMPANY - 2019000002                 GABINO
# ...                                ...                    ...
# 11155  STIM_TREAT_COMPANY - 2019000007                   JOE
# 11156  STIM_TREAT_COMPANY - 2019000007          GABINO/DUSTIN
# 11157  STIM_TREAT_COMPANY - 2019000007                    JIM
# 11158  STIM_TREAT_COMPANY - 2019000007                  ERNEY
# 11159  STIM_TREAT_COMPANY - 2019000007                    EDD
#
#                     DIVERSION_COMPANY  DIVERSION_METHOD  DELIVERY_MODE  \
# 0      DIVERSION_COMPANY - 2019000014         Frac Plug         Casing
# 1      DIVERSION_COMPANY - 2019000003         Frac Plug         Casing
# 2      DIVERSION_COMPANY - 2019000003       Bridge Plug         Casing
# 3      DIVERSION_COMPANY - 2019000006              Ball         Casing
# 4      DIVERSION_COMPANY - 2019000003         Frac Plug         Casing
# ...                               ...               ...            ...
# 11155  DIVERSION_COMPANY - 2019000011         Frac Plug         Casing
# 11156  DIVERSION_COMPANY - 2019000011         Frac Plug         Casing
# 11157  DIVERSION_COMPANY - 2019000008         FRAC PLUG         Casing
# 11158  DIVERSION_COMPANY - 2019000011         Frac Plug         Casing
# 11159  DIVERSION_COMPANY - 2019000011         Frac Plug         Casing
#
#        BOTTOM_HOLE_PRESSURE_METHOD  STIMULATION_RESULT  \
# 0                       Calculated             Success
# 1                       Calculated             Success
# 2                       Calculated             Success
# 3                       Calculated             Success
# 4                       Calculated             Success
# ...                            ...                 ...
# 11155                   Calculated             Success
# 11156                   Calculated             Success
# 11157                   Calculated             Success
# 11158                   Calculated             Success
# 11159                   Calculated             Success
#
#        STIMULATION_RESULT_DETAIL                      STIMTREAT_ID  \
# 0                   Changed Plan  1B23AC2EEC164A7C805637924EF9B662
# 1              According to Plan  5FBA277A2B0F4DF4BDC249BAC046B599
# 2              According to Plan  5D332B226C134DEBAB485423A9FC7180
# 3              According to Plan  0F992D3C969446B0817181E337548581
# 4              According to Plan  5C45FAA30B66416A84572A2CB7818489
# ...                          ...                               ...
# 11155          According to Plan  7929C6965FCA4E20859477200A710E75
# 11156          According to Plan  13869C3EBB484BD299379345B056931D
# 11157             CUT SAND SHORT  A2C6BECB4B59404A8954867074E269B0
# 11158          According to Plan  2E071129C9734CD79766B9ADF7CDA947
# 11159          According to Plan  2BB3E6D5BFEE40B79FE00539A263243A
#
#             FLUID_NAME
# 0           X-link gel
# 1           Slickwater
# 2          Slick Water
# 3           X-link gel
# 4          Slick Water
# ...                ...
# 11155  25# Guar Borate
# 11156       X-link gel
# 11157  25# Guar Borate
# 11158       X-link gel
# 11159       X-link gel
#
# [11160 rows x 149 columns]

# %%
new_stmstg.to_excel("STMSTG_RIG_SCALED_REPLACE_WO_MAX.xlsx")
