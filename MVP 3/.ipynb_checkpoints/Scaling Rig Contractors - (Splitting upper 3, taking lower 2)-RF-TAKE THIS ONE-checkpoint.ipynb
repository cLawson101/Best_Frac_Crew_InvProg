# %% [markdown]
# # Sampling Rig Contractors 2 Small 3 Big
#
# So Seeing how there are 2 small contractors and 3 large contractors, this sampling method will take the entirety of the 2 small contractors and sample the remaining 3 large contractors.
#
# The the smallest of the 3 large contractors will be how many elements are sampled

# %%
from time import time
import numpy as np
import matplotlib.pyplot as plt

from sklearn import metrics
from sklearn.cluster import KMeans
from sklearn.datasets import load_digits
from sklearn.decomposition import PCA
from sklearn.preprocessing import scale

import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split
import os
import torch
from torch import nn
from torch.autograd import Variable
import torch.nn.functional as F

from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Establishing Path

# %%
path = "../SHARED/"

# %% [markdown]
# ## Recompletion data

# %%
# Reading in the data
data_rcompl = pd.read_excel(path + "RCOMPL_KNN_IMPUTED.xlsx")

# %%
# Getting all the contractors
unique_rigs = data_rcompl["CONTRACTOR"].unique()

# %%
# Counting the number of entries for each contractor
for i in unique_rigs:
    temp_pd = data_rcompl[data_rcompl["CONTRACTOR"] == i]
    print(i, " has ", len(temp_pd), " elements.")
# Out:
# CONTRACTOR - 2019000027  has  805  elements.
# CONTRACTOR - 2019000030  has  403  elements.
# CONTRACTOR - 2019000023  has  165  elements.
# CONTRACTOR - 2019000008  has  259  elements.
# CONTRACTOR - 2019000051  has  22  elements.

# %%
# Now partitioning out how many elements to get from each contractor
rcompl_contractor = [
    'CONTRACTOR - 2019000008',
    'CONTRACTOR - 2019000023',
    'CONTRACTOR - 2019000027',
    'CONTRACTOR - 2019000030',
    'CONTRACTOR - 2019000051'
]

# Taking all from the smallest 2 contractors
# Then for the upper 3, will take the same amount as the 3rd smallest contractor
rcompl_sample = [
    259,
    165,
    259,
    259,
    22
]

for i in range(5):
    print(rcompl_contractor[i], " ", rcompl_sample[i])
# Out:
# CONTRACTOR - 2019000008   259
# CONTRACTOR - 2019000023   165
# CONTRACTOR - 2019000027   259
# CONTRACTOR - 2019000030   259
# CONTRACTOR - 2019000051   22

# %%
# Now go ahead and use pandas sample method to get what we need
new_rcompl = pd.DataFrame(columns = data_rcompl.columns)

for i in range(0, len(rcompl_contractor)):
    print(rcompl_contractor[i], " ", rcompl_sample[i])
    temp_pd = data_rcompl[data_rcompl["CONTRACTOR"] == rcompl_contractor[i]]
    temp_pd = temp_pd.sample(n = rcompl_sample[i])
    new_rcompl = new_rcompl.append(temp_pd, ignore_index=True)
# Out:
# CONTRACTOR - 2019000008   259
# CONTRACTOR - 2019000023   165
# CONTRACTOR - 2019000027   259
# CONTRACTOR - 2019000030   259
# CONTRACTOR - 2019000051   22

# %%
new_rcompl
# Out:
#             UWI UWI_SIDETRACK REPORT_START_DATE_YEAR  FRAC_GRADIENT  \
# 0    2019000666             0                   2018            1.0
# 1    2019000620             0                   2017            1.0
# 2    2019000735             0                   2019            1.0
# 3    2019000267             0                   2019            1.0
# 4    2019000666             0                   2018            1.0
# ..          ...           ...                    ...            ...
# 959  2019000278             0                   2019            1.0
# 960  2019000278             0                   2019            1.0
# 961  2019000278             0                   2019            1.0
# 962  2019000278             0                   2019            1.0
# 963  2019000278             0                   2019            1.0
#
#      BREAKDOWN_PRESSURE  HYDROSTATIC_PRESSURE  TREAT_AVG_PRESSURE  \
# 0                7054.0                5770.0              8216.0
# 1                6870.0                5106.0              7415.0
# 2                6533.0                5582.0              9730.0
# 3                6126.0                5200.0              9691.0
# 4                7054.0                5770.0              8239.0
# ..                  ...                   ...                 ...
# 959              8321.0                5143.0              7340.0
# 960              6138.0                5197.4              8972.0
# 961              6045.0                5285.6              9276.0
# 962              5423.0                5122.0              8419.0
# 963              5335.0                5119.2              8561.0
#
#      TREAT_MAX_PRESSURE  TREAT_MIN_PRESSURE PROPPANT_DESIGNED  ...  \
# 0                8596.0              6601.0            291500  ...
# 1                7716.0              6600.0            429000  ...
# 2                9954.0              7803.6            425000  ...
# 3                9816.0              7691.0            351900  ...
# 4                8607.0              8044.0            291500  ...
# ..                  ...                 ...               ...  ...
# 959              8605.0              7618.0           1273750  ...
# 960              9182.0              7618.0            367500  ...
# 961              9466.0              7618.0            367500  ...
# 962              8822.0              7618.0            367500  ...
# 963              9179.0              7618.0            367500  ...
#
#                   DIVERSION_COMPANY DIVERSION_METHOD  DELIVERY_MODE  \
# 0    DIVERSION_COMPANY - 2019000008        PERF PODS         Casing
# 1    DIVERSION_COMPANY - 2019000017         TTS PODS         Casing
# 2    DIVERSION_COMPANY - 2019000011        Frac Plug         Casing
# 3    DIVERSION_COMPANY - 2019000013        PERF PODS         Casing
# 4    DIVERSION_COMPANY - 2019000008        PERF PODS         Casing
# ..                              ...              ...            ...
# 959  DIVERSION_COMPANY - 2019000003              CFP         Casing
# 960  DIVERSION_COMPANY - 2019000003        Frac Plug         Casing
# 961  DIVERSION_COMPANY - 2019000003        Frac Plug         Casing
# 962  DIVERSION_COMPANY - 2019000003        Frac Plug         Casing
# 963  DIVERSION_COMPANY - 2019000003        Frac Plug         Casing
#
#      BOTTOM_HOLE_PRESSURE_METHOD    CLOSURE_PRESSURE_METHOD  \
# 0                     Calculated           Nolte-Smith Calc
# 1                     Calculated           Nolte-Smith Calc
# 2                     Calculated  Pressure Decline Analysis
# 3                     Calculated           Nolte-Smith Calc
# 4                     Calculated           Nolte-Smith Calc
# ..                           ...                        ...
# 959                   Calculated           Nolte-Smith Calc
# 960                   Calculated           Nolte-Smith Calc
# 961                   Calculated           Nolte-Smith Calc
# 962                   Calculated           Nolte-Smith Calc
# 963                   Calculated           Nolte-Smith Calc
#
#      STIMULATION_RESULT  STIMULATION_RESULT_DETAIL  \
# 0               Success          According to Plan
# 1               Success          According to Plan
# 2               Success          According to Plan
# 3               Success          According to Plan
# 4               Success          According to Plan
# ..                  ...                        ...
# 959             Success               Changed Plan
# 960             Success          According to Plan
# 961             Success          According to Plan
# 962             Success          According to Plan
# 963             Success          According to Plan
#
#                          STIMTREAT_ID       FLUID_NAME   SITE_SUPERVISOR
# 0    06E1ED002F6A42E28FD3A0CF6B056B8E  25# Guar Borate       KENNY SMITH
# 1    8DA6CCDF3F90496DB9FFE1EECCEB0E18        XLINK GEL  NICHOLAS STEPHEN
# 2    7F2D51154E08498AA90041E0D86944B0             HVFR    WILLIE O NEILL
# 3    9305FD80203C4178BC7F2C1CE8928D76             HVFR  NICHOLAS STEPHEN
# 4    DA602B9F63674DE0BCC05ED2F7EA03AC  25# Guar Borate       KENNY SMITH
# ..                                ...              ...               ...
# 959  E1367B9C6B8544CA9087635972C31DD9       Slickwater   EFRAIN GONZALES
# 960  717EA2ACBF1543ACAB5AEF4FF8BD8460       Slickwater        Rene Gomez
# 961  B664D012DB3B4A10A816F0D37773A54B       Slickwater     ADEMAR GALVAN
# 962  75175C188E444E75A22E51B19EF69593       Slickwater     ADEMAR GALVAN
# 963  ACA7734DDC7D4EB9AA4213B6C7AD9FA8       Slickwater  HECTOR RODRIGUEZ
#
# [964 rows x 149 columns]

# %%
# Export to shared
new_rcompl.to_excel(path + "RF_RCOMPL_RIG_SCALED.xlsx")

# %% [markdown]
# ## Stimulation stage
# seeing how this is the same just for stimulation stage, comments will be sparse

# %%
data_stmstg = pd.read_excel(path + "STMSTG_KNN_IMPUTED.xlsx")

# %%
# Getting all the contractors
unique_rigs = data_stmstg["CONTRACTOR"].unique()

# %%
# Counting the elements in each contractor
for i in unique_rigs:
    temp_pd = data_stmstg[data_stmstg["CONTRACTOR"] == i]
    print(i, " has ", len(temp_pd), " elements.")
# Out:
# CONTRACTOR - 2019000008  has  3455  elements.
# CONTRACTOR - 2019000027  has  8790  elements.
# CONTRACTOR - 2019000030  has  3825  elements.
# CONTRACTOR - 2019000023  has  1191  elements.
# CONTRACTOR - 2019000051  has  460  elements.

# %%
stmstg_contractor = [
    'CONTRACTOR - 2019000008',
    'CONTRACTOR - 2019000023',
    'CONTRACTOR - 2019000027',
    'CONTRACTOR - 2019000030',
    'CONTRACTOR - 2019000051'
]

# Using the same strategy as before
# fully take lower 2
# sample from upper 3
stmstg_sample = [
    3455,
    1191,
    3455,
    3455,
    460
]
for i in range(5):
    print(stmstg_contractor[i], " ", stmstg_sample[i])
# Out:
# CONTRACTOR - 2019000008   3455
# CONTRACTOR - 2019000023   1191
# CONTRACTOR - 2019000027   3455
# CONTRACTOR - 2019000030   3455
# CONTRACTOR - 2019000051   460

# %%
# use pandas sample function to get our sampled data
new_stmstg = pd.DataFrame(columns = data_stmstg.columns)

for i in range(0, len(stmstg_contractor)):
    print(stmstg_contractor[i], " ", stmstg_sample[i])
    temp_pd = data_stmstg[data_stmstg["CONTRACTOR"] == stmstg_contractor[i]]
    temp_pd = temp_pd.sample(n = stmstg_sample[i])
    new_stmstg = new_stmstg.append(temp_pd, ignore_index=True)
# Out:
# CONTRACTOR - 2019000008   3455
# CONTRACTOR - 2019000023   1191
# CONTRACTOR - 2019000027   3455
# CONTRACTOR - 2019000030   3455
# CONTRACTOR - 2019000051   460

# %%
new_stmstg
# Out:
#               UWI UWI_SIDETRACK FRAC_GRADIENT  BREAKDOWN_PRESSURE  \
# 0      2019000491             0             1              8074.0
# 1      2019000457             0             1              8880.0
# 2      2019000856             2             1              9542.0
# 3      2019000825             0             1              8822.0
# 4      2019000984             0             1              8390.0
# ...           ...           ...           ...                 ...
# 12011  2019000063             0             1              6475.0
# 12012  2019000059             0             1              6715.0
# 12013  2019000061             0             1              6806.0
# 12014  2019000063             0             1              5745.0
# 12015  2019000064             0             1              6300.0
#
#        HYDROSTATIC_PRESSURE  TREAT_AVG_PRESSURE  TREAT_MAX_PRESSURE  \
# 0                    5128.0              9612.0             10069.0
# 1                    5568.0             10305.0             10862.0
# 2                    5595.0             10620.0             10890.0
# 3                    5784.0             10948.0             11142.0
# 4                    5828.0             10469.0             10755.0
# ...                     ...                 ...                 ...
# 12011                5126.0              9687.0             10020.0
# 12012                5048.0             10293.0             10409.0
# 12013                5246.0             10237.0             10402.0
# 12014                5101.0              9757.0              9992.0
# 12015                5110.0             10094.0             10282.0
#
#        TREAT_MIN_PRESSURE PROPPANT_DESIGNED PROPPANT_IN_FORMATION  ...  \
# 0                  6985.0            520000                519860  ...
# 1                  8010.0            520000                522720  ...
# 2                  7278.2            420000                420320  ...
# 3                  8190.0            420000                419960  ...
# 4                  9580.0            420000                420450  ...
# ...                   ...               ...                   ...  ...
# 12011              7780.0            420000                423470  ...
# 12012              7447.8            420000                419570  ...
# 12013              7780.0            420000                420596  ...
# 12014              7780.0            420000                420220  ...
# 12015              7780.0            420000                420000  ...
#
#                     STIM_TREAT_COMPANY  STIM_TREAT_SUPERVISOR  \
# 0      STIM_TREAT_COMPANY - 2019000002                 CARLOS
# 1      STIM_TREAT_COMPANY - 2019000002                 GABINO
# 2      STIM_TREAT_COMPANY - 2019000002                  CANTU
# 3      STIM_TREAT_COMPANY - 2019000002                 DUSTIN
# 4      STIM_TREAT_COMPANY - 2019000002                 GABINO
# ...                                ...                    ...
# 12011  STIM_TREAT_COMPANY - 2019000007                GAMBINO
# 12012  STIM_TREAT_COMPANY - 2019000007                  ERNIE
# 12013  STIM_TREAT_COMPANY - 2019000007                   JOSE
# 12014  STIM_TREAT_COMPANY - 2019000007                 GABINO
# 12015  STIM_TREAT_COMPANY - 2019000007              ED/MIGUEL
#
#                     DIVERSION_COMPANY  DIVERSION_METHOD  DELIVERY_MODE  \
# 0      DIVERSION_COMPANY - 2019000003              Ball         Casing
# 1      DIVERSION_COMPANY - 2019000003         FRAC PLUG         Casing
# 2      DIVERSION_COMPANY - 2019000006         Frac Plug         Casing
# 3      DIVERSION_COMPANY - 2019000003         Frac Plug         Casing
# 4      DIVERSION_COMPANY - 2019000003              Ball         Casing
# ...                               ...               ...            ...
# 12011  DIVERSION_COMPANY - 2019000011         Frac Plug         Casing
# 12012  DIVERSION_COMPANY - 2019000011         Frac Plug         Casing
# 12013  DIVERSION_COMPANY - 2019000011         Frac Plug         Casing
# 12014  DIVERSION_COMPANY - 2019000008         Frac Plug         Casing
# 12015  DIVERSION_COMPANY - 2019000011         Frac Plug         CASING
#
#        BOTTOM_HOLE_PRESSURE_METHOD  STIMULATION_RESULT  \
# 0                       Calculated             Success
# 1                       Calculated             Success
# 2                       Calculated             Success
# 3                       Calculated             Success
# 4                       Calculated             Success
# ...                            ...                 ...
# 12011                   Calculated             Success
# 12012                   Calculated             Success
# 12013                   Calculated             Success
# 12014                   Calculated             Success
# 12015                   Calculated             Success
#
#        STIMULATION_RESULT_DETAIL                      STIMTREAT_ID  \
# 0              According to Plan  6B12FC05AEF64B6DBC82FB85F26545C1
# 1                   Changed Plan  C7553B8BFF6242C2A1D80CB195D99CBF
# 2              According to Plan  86139FBB4FF54F7C881D471BE1684530
# 3              According to Plan  526D201D36B242778EABDDB55CF588C9
# 4              According to Plan  78BE7B2C2744475989B31AB2A1BD69F4
# ...                          ...                               ...
# 12011          According to Plan  FBE19C3D747047E8BAD545C95DCB8C7A
# 12012          According to Plan  B684A7FF7A18416C9642DE466B7881F7
# 12013          According to Plan  BC6EF615A917458EB118A6E01EAC7CF7
# 12014          According to Plan  3A530E6ECDE447F8A905AAE848564478
# 12015          According to Plan  01C3FB19429147E4A799B52ABD2E0FF7
#
#             FLUID_NAME
# 0           25# BORATE
# 1             25#  XL
# 2           X-link gel
# 3      25# Guar Borate
# 4             25#  XL
# ...                ...
# 12011  25# Guar Borate
# 12012  25# Guar Borate
# 12013       X-link gel
# 12014  25# Guar Borate
# 12015       X-link gel
#
# [12016 rows x 149 columns]

# %%
# Export our data
new_stmstg.to_excel(path + "STMSTG_RIG_SCALED.xlsx")
