# %% [markdown]
# # Sampling Rig Contractors - Sampling without max - KNN
#
# Here the thought process is similar to the sampling without replacement, but we understand that amplifying the smaller contractors may negatively impact the over all model. So instead of taking the total number of entries for each contractor and dividing equally, we will take the sum of the lesser 4 contractors and use that to come up with the number of entries to use.

# %%
from time import time
import numpy as np
import matplotlib.pyplot as plt

from sklearn import metrics
from sklearn.cluster import KMeans
from sklearn.datasets import load_digits
from sklearn.decomposition import PCA
from sklearn.preprocessing import scale

import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split
import os
import torch
from torch import nn
from torch.autograd import Variable
import torch.nn.functional as F

from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Establishing Path

# %%
path = "../SHARED/"

# %% [markdown]
# ## Recompletion

# %%
# Reading in data
data_rcompl = pd.read_excel(path + "RCOMPL_KNN_IMPUTED.xlsx")

# %%
# Getting the unique contractors
unique_rigs = data_rcompl["CONTRACTOR"].unique()

# %%
# Get the totals of the contractors
total_entries = []

for i in unique_rigs:
    temp_pd = data_rcompl[data_rcompl["CONTRACTOR"] == i]
    print(i, " has ", len(temp_pd), " elements.")
    total_entries.append(len(temp_pd))
# Out:
# CONTRACTOR - 2019000027  has  805  elements.
# CONTRACTOR - 2019000030  has  403  elements.
# CONTRACTOR - 2019000023  has  165  elements.
# CONTRACTOR - 2019000008  has  259  elements.
# CONTRACTOR - 2019000051  has  22  elements.

# %%
total_entries
# Out:
# [805, 403, 165, 259, 22]

# %%
# Here we will be summing everything up but before we get our samples
# we will remove the largest number of elements and essentially ignore it
# from counting

sum_rcompl = 0

for i in total_entries:
    sum_rcompl += i

tot_samples = (sum_rcompl-805) // 4

# %%
tot_samples
# Out:
# 212

# %%
# knowing our new sample size we go ahead and sampel with replacement
new_rcompl = pd.DataFrame(columns = data_rcompl.columns)

for i in range(0, len(unique_rigs)):
    temp_pd = data_rcompl[data_rcompl["CONTRACTOR"] == unique_rigs[i]]
    temp_pd = temp_pd.sample(n = tot_samples, replace = True)
    new_rcompl = new_rcompl.append(temp_pd, ignore_index=True)

# %%
new_rcompl
# Out:
#              UWI UWI_SIDETRACK REPORT_START_DATE_YEAR  FRAC_GRADIENT  \
# 0     2019001323             0                   2018            1.0
# 1     2019000640             0                   2019            1.0
# 2     2019000298             0                   2019            1.0
# 3     2019000699             0                   2019            1.0
# 4     2019001277             0                   2018            1.0
# ...          ...           ...                    ...            ...
# 1055  2019000278             0                   2019            1.0
# 1056  2019000278             0                   2019            1.0
# 1057  2019000278             0                   2019            1.0
# 1058  2019000278             0                   2019            1.0
# 1059  2019000278             0                   2019            1.0
#
#       BREAKDOWN_PRESSURE  HYDROSTATIC_PRESSURE  TREAT_AVG_PRESSURE  \
# 0                 8400.0                5570.0              7774.0
# 1                 7389.0                5628.0              9823.0
# 2                 9120.0                5545.6              9472.0
# 3                 8459.0                5483.0              8949.0
# 4                 8916.0                5293.0              9059.0
# ...                  ...                   ...                 ...
# 1055              5643.0                5119.2              8976.0
# 1056              6045.0                5285.6              9276.0
# 1057              5335.0                5119.2              8561.0
# 1058              6138.0                5197.4              8972.0
# 1059              5299.0                5129.0              8236.0
#
#       TREAT_MAX_PRESSURE  TREAT_MIN_PRESSURE PROPPANT_DESIGNED  ...  \
# 0                 9086.0              6169.8            250000  ...
# 1                10191.0              7618.0            384000  ...
# 2                 9583.0              7346.0            328750  ...
# 3                 9569.0              7346.0            328750  ...
# 4                 9373.0              6445.0            325000  ...
# ...                  ...                 ...               ...  ...
# 1055              9310.0              7618.0            367500  ...
# 1056              9466.0              7618.0            367500  ...
# 1057              9179.0              7618.0            367500  ...
# 1058              9182.0              7618.0            367500  ...
# 1059              8704.0              7618.0            367500  ...
#
#                    DIVERSION_COMPANY DIVERSION_METHOD  DELIVERY_MODE  \
# 0     DIVERSION_COMPANY - 2019000003              CFP         Casing
# 1     DIVERSION_COMPANY - 2019000007        Frac Plug         Casing
# 2     DIVERSION_COMPANY - 2019000003      Bridge Plug         Casing
# 3     DIVERSION_COMPANY - 2019000007        Frac Plug         Casing
# 4     DIVERSION_COMPANY - 2019000003             Ball         Casing
# ...                              ...              ...            ...
# 1055  DIVERSION_COMPANY - 2019000003        Frac Plug         Casing
# 1056  DIVERSION_COMPANY - 2019000003        Frac Plug         Casing
# 1057  DIVERSION_COMPANY - 2019000003        Frac Plug         Casing
# 1058  DIVERSION_COMPANY - 2019000003        Frac Plug         Casing
# 1059  DIVERSION_COMPANY - 2019000003        Frac Plug         Casing
#
#       BOTTOM_HOLE_PRESSURE_METHOD  CLOSURE_PRESSURE_METHOD  \
# 0                      Calculated         Nolte-Smith Calc
# 1                      Calculated         Nolte-Smith Calc
# 2                      Calculated         Nolte-Smith Calc
# 3                      Calculated         Nolte-Smith Calc
# 4                      Calculated         Nolte-Smith Calc
# ...                           ...                      ...
# 1055                   Calculated         Nolte-Smith Calc
# 1056                   Calculated         Nolte-Smith Calc
# 1057                   Calculated         Nolte-Smith Calc
# 1058                   Calculated         Nolte-Smith Calc
# 1059                   Calculated         Nolte-Smith Calc
#
#       STIMULATION_RESULT  STIMULATION_RESULT_DETAIL  \
# 0                Success          According to Plan
# 1                Success          According to Plan
# 2                Success          According to Plan
# 3                Success          According to Plan
# 4                Success          According to Plan
# ...                  ...                        ...
# 1055             Success          According to Plan
# 1056             Success          According to Plan
# 1057             Success          According to Plan
# 1058             Success          According to Plan
# 1059             Success          According to Plan
#
#                           STIMTREAT_ID         FLUID_NAME  \
# 0     A55C587EB3D04470B2CED5E8F6FF5907             XL GEL
# 1     5A66BAE9F073444DBB57D654933FD6BB   LX-6 (FDP -1298)
# 2     4937B9E0A2F74D2F8B16F2BF4EE207AA         Slickwater
# 3     61B3A2FBE14F483A81121BE78565D49D         Slickwater
# 4     9561C488832A41F8B6BE8ED61618D19D  25 PPT XL HYBOR G
# ...                                ...                ...
# 1055  5832A76BE5C345EAA840EC4863988AA9         Slickwater
# 1056  B664D012DB3B4A10A816F0D37773A54B         Slickwater
# 1057  ACA7734DDC7D4EB9AA4213B6C7AD9FA8         Slickwater
# 1058  717EA2ACBF1543ACAB5AEF4FF8BD8460         Slickwater
# 1059  D98C57C66E2F4E2F8472EBDB1EB3984D         Slickwater
#
#                   SITE_SUPERVISOR
# 0     KIN TUCKER/NICHOLAS STEPHEN
# 1                 EFRAIN GONZALES
# 2                     DAVE MALOTT
# 3                   DANIEL NELSON
# 4                     KENNY SMITH
# ...                           ...
# 1055              EFRAIN GONZALES
# 1056                ADEMAR GALVAN
# 1057             HECTOR RODRIGUEZ
# 1058                   Rene Gomez
# 1059              EFRAIN GONZALES
#
# [1060 rows x 149 columns]

# %%
new_rcompl.to_excel(path + "RCOMPL_RIG_SCALED_REPLACE_WO_MAX.xlsx")

# %% [markdown]
# ## Stimulation stage

# %%
#Read in data
data_stmstg = pd.read_excel(path + "STMSTG_KNN_IMPUTED.xlsx")

# %%
# Get the contractors
unique_rigs = data_stmstg["CONTRACTOR"].unique()

# %%
# see totals for the different contractors
total_entries = []

for i in unique_rigs:
    temp_pd = data_stmstg[data_stmstg["CONTRACTOR"] == i]
    print(i, " has ", len(temp_pd), " elements.")
    total_entries.append(len(temp_pd))
# Out:
# CONTRACTOR - 2019000008  has  3455  elements.
# CONTRACTOR - 2019000027  has  8790  elements.
# CONTRACTOR - 2019000030  has  3825  elements.
# CONTRACTOR - 2019000023  has  1191  elements.
# CONTRACTOR - 2019000051  has  460  elements.

# %%
total_entries
# Out:
# [3455, 8790, 3825, 1191, 460]

# %%
# Here we will be summing everything up but before we get our samples
# we will remove the largest number of elements and essentially ignore it
# from counting

sum_stmstg = 0

for i in total_entries:
    sum_stmstg += i

print("total sum", sum_stmstg)
tot_samples = (sum_stmstg-8790) // 4
# Out:
# total sum 17721

# %%
tot_samples
# Out:
# 2232

# %%
# knowing our new sample size we go ahead and sampel with replacement
new_stmstg = pd.DataFrame(columns = data_stmstg.columns)

for i in range(0, len(unique_rigs)):
    temp_pd = data_stmstg[data_stmstg["CONTRACTOR"] == unique_rigs[i]]
    temp_pd = temp_pd.sample(n = tot_samples, replace = True)
    new_stmstg = new_stmstg.append(temp_pd, ignore_index=True)

# %%
new_stmstg
# Out:
#               UWI UWI_SIDETRACK FRAC_GRADIENT  BREAKDOWN_PRESSURE  \
# 0      2019000500             0             1              9904.0
# 1      2019000492             0             1              8315.0
# 2      2019000500             0             1              6576.0
# 3      2019000485             0             1              8107.0
# 4      2019000505             0             1              7246.0
# ...           ...           ...           ...                 ...
# 11155  2019000064             0             1              7652.0
# 11156  2019000065             0             1              7144.0
# 11157  2019000061             0             1              6398.0
# 11158  2019000066             0             1              7542.0
# 11159  2019000062             0             1              8224.0
#
#        HYDROSTATIC_PRESSURE  TREAT_AVG_PRESSURE  TREAT_MAX_PRESSURE  \
# 0                    5029.0             10656.0             10865.0
# 1                    5182.0              9924.0             10281.0
# 2                    4983.0             10610.0             10952.0
# 3                    5461.0             10257.0             10793.0
# 4                    5074.0              9834.0             10308.0
# ...                     ...                 ...                 ...
# 11155                5057.0              9953.0             10197.0
# 11156                5113.0              9939.0             10306.0
# 11157                5155.0             10111.0             10313.0
# 11158                5143.0              9965.0             10220.0
# 11159                5082.0             10014.0             10232.0
#
#        TREAT_MIN_PRESSURE PROPPANT_DESIGNED PROPPANT_IN_FORMATION  ...  \
# 0                     0.0            520000                520710  ...
# 1                  8315.0            520000                520080  ...
# 2                  6429.0            520000                519440  ...
# 3                  7950.0            520000                519540  ...
# 4                  6700.0            520000                519920  ...
# ...                   ...               ...                   ...  ...
# 11155              7780.0            420000                419530  ...
# 11156              8081.2            420000                425360  ...
# 11157              7780.0            420000                421760  ...
# 11158              7780.0            420000                420450  ...
# 11159              7794.6            420000                418680  ...
#
#                     STIM_TREAT_COMPANY  STIM_TREAT_SUPERVISOR  \
# 0      STIM_TREAT_COMPANY - 2019000002                 ROBERT
# 1      STIM_TREAT_COMPANY - 2019000002                 DUSTIN
# 2      STIM_TREAT_COMPANY - 2019000002                 ROBERT
# 3      STIM_TREAT_COMPANY - 2019000002                 DUSTIN
# 4      STIM_TREAT_COMPANY - 2019000002                  ERNIE
# ...                                ...                    ...
# 11155  STIM_TREAT_COMPANY - 2019000007          GABINO/DUSTIN
# 11156  STIM_TREAT_COMPANY - 2019000007                 JAVIER
# 11157  STIM_TREAT_COMPANY - 2019000007          GABINO/DUSTIN
# 11158  STIM_TREAT_COMPANY - 2019000007                    DAN
# 11159  STIM_TREAT_COMPANY - 2019000007                 GABINO
#
#                     DIVERSION_COMPANY  DIVERSION_METHOD  DELIVERY_MODE  \
# 0      DIVERSION_COMPANY - 2019000003              Ball         Casing
# 1      DIVERSION_COMPANY - 2019000003              Ball         Casing
# 2      DIVERSION_COMPANY - 2019000003              Ball         Casing
# 3      DIVERSION_COMPANY - 2019000003         Frac Plug         Casing
# 4      DIVERSION_COMPANY - 2019000003              Ball         Casing
# ...                               ...               ...            ...
# 11155  DIVERSION_COMPANY - 2019000011         Frac Plug         Casing
# 11156  DIVERSION_COMPANY - 2019000011         FRAC PLUG         Casing
# 11157  DIVERSION_COMPANY - 2019000011         Frac Plug         Casing
# 11158  DIVERSION_COMPANY - 2019000006         Frac Plug         Casing
# 11159  DIVERSION_COMPANY - 2019000011         Frac Plug         Casing
#
#        BOTTOM_HOLE_PRESSURE_METHOD  STIMULATION_RESULT  \
# 0                       Calculated             Success
# 1                       Calculated             Success
# 2                       Calculated             Success
# 3                       Calculated             Success
# 4                       Calculated             Success
# ...                            ...                 ...
# 11155                   Calculated             Success
# 11156                   Calculated             Success
# 11157                   Calculated             Success
# 11158                   Calculated             Success
# 11159                   Calculated             Success
#
#        STIMULATION_RESULT_DETAIL                      STIMTREAT_ID  \
# 0              According to Plan  F835E38BDE3F4894AACB0CA5EB15733D
# 1              According to Plan  3DB83BDE155E469791567DD9C68CA570
# 2              According to Plan  4EC2EE8C8D8448B5AD27E5E68D71BE8A
# 3              According to Plan  EC48305189C74C1C9FA500056C78ED71
# 4              According to Plan  28E5D9355DDF4562B0F89E9415D5C74B
# ...                          ...                               ...
# 11155          According to Plan  DE0C0C1AA5DE41E89A81088105F0A005
# 11156           Acording to Plan  B03F40FAE46843B4B45BB15D0419CA2D
# 11157          According to Plan  0DB54C37E7664969AB3903688378BE63
# 11158          According to Plan  712342EC6D554B3786546147B5BB2C23
# 11159          According to Plan  D1D99E57B465475E85ACD8D239AC9DB0
#
#             FLUID_NAME
# 0               X-LINK
# 1          Slick Water
# 2               X-LINK
# 3          Slick Water
# 4             25#  XL
# ...                ...
# 11155       X-link gel
# 11156  25# Guar Borate
# 11157       X-link gel
# 11158       X-link gel
# 11159  25# Guar Borate
#
# [11160 rows x 149 columns]

# %%
# Export data
new_stmstg.to_excel(path + "STMSTG_RIG_SCALED_REPLACE_WO_MAX.xlsx")
