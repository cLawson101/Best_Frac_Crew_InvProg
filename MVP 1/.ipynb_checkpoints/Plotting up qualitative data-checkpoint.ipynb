# %% [markdown]
# # Plotting up qualitative data

# %% [markdown]
# Finding correlations with pairplots for the files given.

# %%
import pandas as pd
import matplotlib.pyplot as plt

import numpy as np
import seaborn as sns
import os
import missingno as msno
import warnings

# %%
path= "../SHARED/"
files = [
    "clean_top_cross_bu_dnc_stim_stage_detail.xlsx",
    "clean_bot_cross_bu_dnc_stim_stage_detail.xlsx",
    "clean_gcbu_dnc_recompletions.xlsx",
    "clean_gcbu_dnc_stim_stage.xlsx",
    "clean_monthly_production.xlsx"
]

# %%
df_1_a = pd.read_excel(path + files[0])
df_1_b = pd.read_excel(path + files[1])
df_2 = pd.read_excel(path + files[2])
df_3 = pd.read_excel(path + files[3])
df_4 = pd.read_excel(path + files[4])

# %% [markdown]
# ## File 2

# %%
qual_features = df_2.select_dtypes(include=[np.object])
qual_features.columns
# Out:
# Index(['#WELL_NAME', 'CURRENT_STATUS', 'JOB_CATEGORY', 'JOB_START_DATE',
#        'JOB_END_DATE', 'JOB_STATUS', 'LIKE_KIND', 'PROJECT_TYPE',
#        'PHASE_START_DATE', 'PHASE_END_DATE', 'PHASE', 'JOB_OP_CODE', 'RIG_ID',
#        'RIG_ACCEPT_DATE', 'RIG_RELEASE_DATE', 'RIG_TYPE', 'CONTRACTOR',
#        'REPORT_START_DATE', 'REPORT_END_DATE', 'STIMULATION_TREAT_DATE',
#        'STIMULATION_TREAT_TYPE', 'STIM_TREAT_COMPANY', 'STIM_TREAT_SUPERVISOR',
#        'DIVERSION_COMPANY', 'DIVERSION_METHOD', 'DELIVERY_MODE',
#        'BOTTOM_HOLE_PRESSURE_METHOD', 'CLOSURE_PRESSURE_METHOD',
#        'STIMULATION_RESULT', 'STIMULATION_RESULT_DETAIL', 'STG_START_DATE',
#        'STG_END_DATE', 'STIMTREAT_ID', 'FLUID_NAME', 'SITE_SUPERVISOR',
#        'STIM_TREAT_REMARK', 'STG_REMARK'],
#       dtype='object')

# %%
qual_features.head()
# Out:
#           #WELL_NAME CURRENT_STATUS JOB_CATEGORY       JOB_START_DATE  \
# 0  WELL - 2019000699      Producing  COMPLETIONS  12/16/2018 06:00:00
# 1  WELL - 2019000665      Producing  COMPLETIONS  01/21/2018 10:00:00
# 2  WELL - 2019000347      Producing  COMPLETIONS  08/31/2017 13:00:00
# 3  WELL - 2019001412      Producing  COMPLETIONS  02/13/2019 07:30:00
# 4  WELL - 2019001390      Producing  COMPLETIONS  04/04/2019 07:30:00
#
#           JOB_END_DATE JOB_STATUS                   LIKE_KIND  PROJECT_TYPE  \
# 0  10/12/2019 10:00:00  COMPLETED  OCM - MECHANICAL ISOLATION  RECOMPLETION
# 1  10/09/2018 07:00:00  COMPLETED                OCM - PP TUB  RECOMPLETION
# 2                  NaN        NaN                OCM - PP PUC  RECOMPLETION
# 3                  NaN        NaN  OCM - MECHANICAL ISOLATION  RECOMPLETION
# 4  06/15/2019 18:00:00        NaN  OCM - MECHANICAL ISOLATION  RECOMPLETION
#
#       PHASE_START_DATE       PHASE_END_DATE  ... CLOSURE_PRESSURE_METHOD  \
# 0  01/11/2019 06:00:00  02/06/2019 07:00:00  ...                     NaN
# 1  01/27/2018 06:00:00  02/23/2018 18:00:00  ...                     NaN
# 2  09/07/2017 00:00:00  10/29/2017 17:00:00  ...        Nolte-Smith Calc
# 3  03/04/2019 16:30:00  04/14/2019 16:00:00  ...                     NaN
# 4  04/23/2019 07:00:00  06/15/2019 18:00:00  ...                     NaN
#
#   STIMULATION_RESULT STIMULATION_RESULT_DETAIL       STG_START_DATE  \
# 0            Success         According to Plan  01/28/2019 08:05:00
# 1            Success         According to Plan  02/19/2018 14:40:00
# 2            Success         According to Plan  10/26/2017 10:13:00
# 3            Success         According to Plan  03/25/2019 14:05:00
# 4            Success         According to Plan  06/13/2019 07:17:00
#
#           STG_END_DATE                      STIMTREAT_ID   FLUID_NAME  \
# 0  01/28/2019 10:05:00  A6066AE1E85F4B1DB15D9940B5FBBEBF   Slickwater
# 1  02/20/2018 00:19:00  6ACEA3AEC54E415B8251B86897A229F3  FRESH WATER
# 2  10/26/2017 12:45:00  29626CB5494D45ACB9C7723B028E9DEF  Slick Water
# 3  03/25/2019 15:34:00  DCCB82735EEA4540A1C0C402180C5A45       FRP-1S
# 4  06/13/2019 09:19:00  B8733A01BFFD46CC8CCDE726BD4B484B       FRP-1S
#
#   SITE_SUPERVISOR                                  STIM_TREAT_REMARK  \
# 0      MIKE HOOSE  STAGE: 1 FRAC OPERATIONSSTART TIME:  0805 HRS ...
# 1             NaN  STAGE: 1 REFRAC OPERATIONSSTART TIME: 14:40 HR...
# 2             NaN  STAGE: 2 FRAC OPSTART TIME: 10:13 HRS       FI...
# 3   CHRIS SANCHEZ  STAGE: 1 FRAC OPERATIONSSTART TIME:  14:05 HRS...
# 4       JW KRAMER  STAGE: 27  RE-FRAC OPERATIONSSTART TIME:  07:1...
#
#                                           STG_REMARK
# 0  STAGE: 1 FRAC OPERATIONSSTART TIME:  0805 HRS ...
# 1  STAGE: 1 REFRAC OPERATIONSSTART TIME: 14:40 HR...
# 2  STAGE: 2 FRAC OPSTART TIME: 10:13 HRS       FI...
# 3  STAGE: 1 FRAC OPERATIONSSTART TIME:  14:05 HRS...
# 4  STAGE: 27  RE-FRAC OPERATIONSSTART TIME:  07:1...
#
# [5 rows x 37 columns]

# %%
for feature in qual_features:
    print("%27s: %4d" % (feature, len(qual_features[feature].unique())))
# Out:
#                  #WELL_NAME:   67
#              CURRENT_STATUS:    1
#                JOB_CATEGORY:    1
#              JOB_START_DATE:   67
#                JOB_END_DATE:   27
#                  JOB_STATUS:    3
#                   LIKE_KIND:    5
#                PROJECT_TYPE:    1
#            PHASE_START_DATE:   67
#              PHASE_END_DATE:   60
#                       PHASE:    1
#                 JOB_OP_CODE:    1
#                      RIG_ID:    7
#             RIG_ACCEPT_DATE:   63
#            RIG_RELEASE_DATE:   64
#                    RIG_TYPE:    2
#                  CONTRACTOR:    5
#           REPORT_START_DATE:  286
#             REPORT_END_DATE:  286
#      STIMULATION_TREAT_DATE: 1653
#      STIMULATION_TREAT_TYPE:    4
#          STIM_TREAT_COMPANY:    6
#       STIM_TREAT_SUPERVISOR:   28
#           DIVERSION_COMPANY:   13
#            DIVERSION_METHOD:   20
#               DELIVERY_MODE:    3
# BOTTOM_HOLE_PRESSURE_METHOD:    2
#     CLOSURE_PRESSURE_METHOD:    3
#          STIMULATION_RESULT:    3
#   STIMULATION_RESULT_DETAIL:    4
#              STG_START_DATE: 1653
#                STG_END_DATE: 1652
#                STIMTREAT_ID: 1654
#                  FLUID_NAME:   40
#             SITE_SUPERVISOR:   69
#           STIM_TREAT_REMARK: 1654
#                  STG_REMARK: 1654

# %%
# Getting rid of dates as these will be handled 
# differently from other qualitative features
cur_features = [feature for feature in qual_features if not "DATE" in feature]
cur_features
# Out:
# ['#WELL_NAME',
#  'CURRENT_STATUS',
#  'JOB_CATEGORY',
#  'JOB_STATUS',
#  'LIKE_KIND',
#  'PROJECT_TYPE',
#  'PHASE',
#  'JOB_OP_CODE',
#  'RIG_ID',
#  'RIG_TYPE',
#  'CONTRACTOR',
#  'STIMULATION_TREAT_TYPE',
#  'STIM_TREAT_COMPANY',
#  'STIM_TREAT_SUPERVISOR',
#  'DIVERSION_COMPANY',
#  'DIVERSION_METHOD',
#  'DELIVERY_MODE',
#  'BOTTOM_HOLE_PRESSURE_METHOD',
#  'CLOSURE_PRESSURE_METHOD',
#  'STIMULATION_RESULT',
#  'STIMULATION_RESULT_DETAIL',
#  'STIMTREAT_ID',
#  'FLUID_NAME',
#  'SITE_SUPERVISOR',
#  'STIM_TREAT_REMARK',
#  'STG_REMARK']

# %%
qual_features = df_2[cur_features]

# %%
for feature in qual_features:
    print("%27s: %4d" % (feature, len(qual_features[feature].unique())))
# Out:
#                  #WELL_NAME:   67
#              CURRENT_STATUS:    1
#                JOB_CATEGORY:    1
#                  JOB_STATUS:    3
#                   LIKE_KIND:    5
#                PROJECT_TYPE:    1
#                       PHASE:    1
#                 JOB_OP_CODE:    1
#                      RIG_ID:    7
#                    RIG_TYPE:    2
#                  CONTRACTOR:    5
#      STIMULATION_TREAT_TYPE:    4
#          STIM_TREAT_COMPANY:    6
#       STIM_TREAT_SUPERVISOR:   28
#           DIVERSION_COMPANY:   13
#            DIVERSION_METHOD:   20
#               DELIVERY_MODE:    3
# BOTTOM_HOLE_PRESSURE_METHOD:    2
#     CLOSURE_PRESSURE_METHOD:    3
#          STIMULATION_RESULT:    3
#   STIMULATION_RESULT_DETAIL:    4
#                STIMTREAT_ID: 1654
#                  FLUID_NAME:   40
#             SITE_SUPERVISOR:   69
#           STIM_TREAT_REMARK: 1654
#                  STG_REMARK: 1654

# %%
# If a qualitative feature only has 1 unique element, then delete
single_element = [feature for feature in qual_features if len(qual_features[feature].unique()) != 1]
single_element
# Out:
# ['#WELL_NAME',
#  'JOB_STATUS',
#  'LIKE_KIND',
#  'RIG_ID',
#  'RIG_TYPE',
#  'CONTRACTOR',
#  'STIMULATION_TREAT_TYPE',
#  'STIM_TREAT_COMPANY',
#  'STIM_TREAT_SUPERVISOR',
#  'DIVERSION_COMPANY',
#  'DIVERSION_METHOD',
#  'DELIVERY_MODE',
#  'BOTTOM_HOLE_PRESSURE_METHOD',
#  'CLOSURE_PRESSURE_METHOD',
#  'STIMULATION_RESULT',
#  'STIMULATION_RESULT_DETAIL',
#  'STIMTREAT_ID',
#  'FLUID_NAME',
#  'SITE_SUPERVISOR',
#  'STIM_TREAT_REMARK',
#  'STG_REMARK']

# %%
qual_features = df_2[single_element]
qual_features
# Out:
#              #WELL_NAME JOB_STATUS                   LIKE_KIND  \
# 0     WELL - 2019000699  COMPLETED  OCM - MECHANICAL ISOLATION
# 1     WELL - 2019000665  COMPLETED                OCM - PP TUB
# 2     WELL - 2019000347        NaN                OCM - PP PUC
# 3     WELL - 2019001412        NaN  OCM - MECHANICAL ISOLATION
# 4     WELL - 2019001390        NaN  OCM - MECHANICAL ISOLATION
# ...                 ...        ...                         ...
# 1649  WELL - 2019000628        NaN  OCM - MECHANICAL ISOLATION
# 1650  WELL - 2019000628        NaN  OCM - MECHANICAL ISOLATION
# 1651  WELL - 2019000628        NaN  OCM - MECHANICAL ISOLATION
# 1652  WELL - 2019000628        NaN  OCM - MECHANICAL ISOLATION
# 1653  WELL - 2019000628        NaN  OCM - MECHANICAL ISOLATION
#
#                    RIG_ID    RIG_TYPE               CONTRACTOR  \
# 0     RIG_ID - 2019000082  FRAC EQUIP  CONTRACTOR - 2019000027
# 1     RIG_ID - 2019000098  FRAC EQUIP  CONTRACTOR - 2019000030
# 2     RIG_ID - 2019000084  FRAC EQUIP  CONTRACTOR - 2019000027
# 3     RIG_ID - 2019000098  FRAC EQUIP  CONTRACTOR - 2019000030
# 4     RIG_ID - 2019000098  FRAC EQUIP  CONTRACTOR - 2019000030
# ...                   ...         ...                      ...
# 1649  RIG_ID - 2019000098  FRAC EQUIP  CONTRACTOR - 2019000030
# 1650  RIG_ID - 2019000098  FRAC EQUIP  CONTRACTOR - 2019000030
# 1651  RIG_ID - 2019000098  FRAC EQUIP  CONTRACTOR - 2019000030
# 1652  RIG_ID - 2019000098  FRAC EQUIP  CONTRACTOR - 2019000030
# 1653  RIG_ID - 2019000098  FRAC EQUIP  CONTRACTOR - 2019000030
#
#      STIMULATION_TREAT_TYPE               STIM_TREAT_COMPANY  \
# 0        Hydraulic Fracture  STIM_TREAT_COMPANY - 2019000004
# 1        Hydraulic Fracture  STIM_TREAT_COMPANY - 2019000005
# 2        Hydraulic Fracture  STIM_TREAT_COMPANY - 2019000004
# 3        Hydraulic Fracture  STIM_TREAT_COMPANY - 2019000005
# 4        Hydraulic Fracture  STIM_TREAT_COMPANY - 2019000005
# ...                     ...                              ...
# 1649     Hydraulic Fracture  STIM_TREAT_COMPANY - 2019000005
# 1650     Hydraulic Fracture  STIM_TREAT_COMPANY - 2019000005
# 1651     Hydraulic Fracture  STIM_TREAT_COMPANY - 2019000005
# 1652     Hydraulic Fracture  STIM_TREAT_COMPANY - 2019000005
# 1653     Hydraulic Fracture  STIM_TREAT_COMPANY - 2019000005
#
#      STIM_TREAT_SUPERVISOR               DIVERSION_COMPANY  ... DELIVERY_MODE  \
# 0                      NaN  DIVERSION_COMPANY - 2019000007  ...        Casing
# 1                     JEFF  DIVERSION_COMPANY - 2019000037  ...        Casing
# 2                   STG 27  DIVERSION_COMPANY - 2019000003  ...        Casing
# 3                      NaN  DIVERSION_COMPANY - 2019000007  ...        Casing
# 4                      NaN                             NaN  ...        Casing
# ...                    ...                             ...  ...           ...
# 1649                   NaN  DIVERSION_COMPANY - 2019000007  ...        Casing
# 1650                   NaN  DIVERSION_COMPANY - 2019000007  ...        Casing
# 1651                   NaN  DIVERSION_COMPANY - 2019000007  ...        Casing
# 1652                   NaN  DIVERSION_COMPANY - 2019000007  ...        Casing
# 1653                   NaN  DIVERSION_COMPANY - 2019000007  ...        Casing
#
#      BOTTOM_HOLE_PRESSURE_METHOD CLOSURE_PRESSURE_METHOD STIMULATION_RESULT  \
# 0                            NaN                     NaN            Success
# 1                            NaN                     NaN            Success
# 2                     Calculated        Nolte-Smith Calc            Success
# 3                            NaN                     NaN            Success
# 4                            NaN                     NaN            Success
# ...                          ...                     ...                ...
# 1649                         NaN                     NaN            Success
# 1650                         NaN                     NaN            Success
# 1651                         NaN                     NaN            Success
# 1652                         NaN                     NaN            Success
# 1653                         NaN                     NaN            Success
#
#      STIMULATION_RESULT_DETAIL                      STIMTREAT_ID   FLUID_NAME  \
# 0            According to Plan  A6066AE1E85F4B1DB15D9940B5FBBEBF   Slickwater
# 1            According to Plan  6ACEA3AEC54E415B8251B86897A229F3  FRESH WATER
# 2            According to Plan  29626CB5494D45ACB9C7723B028E9DEF  Slick Water
# 3            According to Plan  DCCB82735EEA4540A1C0C402180C5A45       FRP-1S
# 4            According to Plan  B8733A01BFFD46CC8CCDE726BD4B484B       FRP-1S
# ...                        ...                               ...          ...
# 1649         According to Plan  3378EA55ECFB4D998B852424A305E2BF   Slickwater
# 1650         According to Plan  D59E4DC0E1654C11B392325DACBEBD11   Slickwater
# 1651         According to Plan  4BC64FC4AF8E463989399F926EFD55D2   Slickwater
# 1652         According to Plan  C464F9B9992947379161C633C1822EA9   Slickwater
# 1653         According to Plan  0FC2C86779A146D19DA60CFA5075FE4A   Slickwater
#
#      SITE_SUPERVISOR                                  STIM_TREAT_REMARK  \
# 0         MIKE HOOSE  STAGE: 1 FRAC OPERATIONSSTART TIME:  0805 HRS ...
# 1                NaN  STAGE: 1 REFRAC OPERATIONSSTART TIME: 14:40 HR...
# 2                NaN  STAGE: 2 FRAC OPSTART TIME: 10:13 HRS       FI...
# 3      CHRIS SANCHEZ  STAGE: 1 FRAC OPERATIONSSTART TIME:  14:05 HRS...
# 4          JW KRAMER  STAGE: 27  RE-FRAC OPERATIONSSTART TIME:  07:1...
# ...              ...                                                ...
# 1649     SEAN CHANCE  STAGE: 50 FRAC OPERATIONSSTART TIME: 15:26 HRS...
# 1650   NATHAN JAYROE  STAGE: 51 FRAC OPERATIONSSTART TIME: 18:21 HRS...
# 1651   NATHAN JAYROE  STAGE: 52 FRAC OPERATIONSSTART TIME: 21:27 HRS...
# 1652   NATHAN JAYROE  STAGE: 53 FRAC OPERATIONSSTART TIME: 00:30 HRS...
# 1653     TORREY MAWK  STAGE: 54 FRAC OPERATIONSSTART TIME: 03:35 HRS...
#
#                                              STG_REMARK
# 0     STAGE: 1 FRAC OPERATIONSSTART TIME:  0805 HRS ...
# 1     STAGE: 1 REFRAC OPERATIONSSTART TIME: 14:40 HR...
# 2     STAGE: 2 FRAC OPSTART TIME: 10:13 HRS       FI...
# 3     STAGE: 1 FRAC OPERATIONSSTART TIME:  14:05 HRS...
# 4     STAGE: 27  RE-FRAC OPERATIONSSTART TIME:  07:1...
# ...                                                 ...
# 1649  STAGE: 50 FRAC OPERATIONSSTART TIME: 15:26 HRS...
# 1650  STAGE: 51 FRAC OPERATIONSSTART TIME: 18:21 HRS...
# 1651  STAGE: 52 FRAC OPERATIONSSTART TIME: 21:27 HRS...
# 1652  STAGE: 53 FRAC OPERATIONSSTART TIME: 00:30 HRS...
# 1653  STAGE: 54 FRAC OPERATIONSSTART TIME: 03:35 HRS...
#
# [1654 rows x 21 columns]

# %%
for feature in qual_features:
    print("%27s: %4d" % (feature, len(qual_features[feature].unique())))
# Out:
#                  #WELL_NAME:   67
#                  JOB_STATUS:    3
#                   LIKE_KIND:    5
#                      RIG_ID:    7
#                    RIG_TYPE:    2
#                  CONTRACTOR:    5
#      STIMULATION_TREAT_TYPE:    4
#          STIM_TREAT_COMPANY:    6
#       STIM_TREAT_SUPERVISOR:   28
#           DIVERSION_COMPANY:   13
#            DIVERSION_METHOD:   20
#               DELIVERY_MODE:    3
# BOTTOM_HOLE_PRESSURE_METHOD:    2
#     CLOSURE_PRESSURE_METHOD:    3
#          STIMULATION_RESULT:    3
#   STIMULATION_RESULT_DETAIL:    4
#                STIMTREAT_ID: 1654
#                  FLUID_NAME:   40
#             SITE_SUPERVISOR:   69
#           STIM_TREAT_REMARK: 1654
#                  STG_REMARK: 1654

# %%
to_remove = [
    "#WELL_NAME",
    "SITE_SUPERVISOR",
    "STIM_TREAT_SUPERVISOR",
    "STIMTREAT_ID",
    "STIM_TREAT_REMARK",
    "STG_REMARK"
]

qual_features = qual_features.drop(columns = to_remove)

# %%
for feature in qual_features:
    print("%27s: %4d" % (feature, len(qual_features[feature].unique())))
# Out:
#                  JOB_STATUS:    3
#                   LIKE_KIND:    5
#                      RIG_ID:    7
#                    RIG_TYPE:    2
#                  CONTRACTOR:    5
#      STIMULATION_TREAT_TYPE:    4
#          STIM_TREAT_COMPANY:    6
#           DIVERSION_COMPANY:   13
#            DIVERSION_METHOD:   20
#               DELIVERY_MODE:    3
# BOTTOM_HOLE_PRESSURE_METHOD:    2
#     CLOSURE_PRESSURE_METHOD:    3
#          STIMULATION_RESULT:    3
#   STIMULATION_RESULT_DETAIL:    4
#                  FLUID_NAME:   40

# %%
qual_features.columns
# Out:
# Index(['JOB_STATUS', 'LIKE_KIND', 'RIG_ID', 'RIG_TYPE', 'CONTRACTOR',
#        'STIMULATION_TREAT_TYPE', 'STIM_TREAT_COMPANY', 'DIVERSION_COMPANY',
#        'DIVERSION_METHOD', 'DELIVERY_MODE', 'BOTTOM_HOLE_PRESSURE_METHOD',
#        'CLOSURE_PRESSURE_METHOD', 'STIMULATION_RESULT',
#        'STIMULATION_RESULT_DETAIL', 'FLUID_NAME'],
#       dtype='object')

# %%
for feature in qual_features.columns:
    qual_features[feature] = qual_features[feature].astype('category')

# %%
qual_features.dtypes
# Out:
# JOB_STATUS                     category
# LIKE_KIND                      category
# RIG_ID                         category
# RIG_TYPE                       category
# CONTRACTOR                     category
# STIMULATION_TREAT_TYPE         category
# STIM_TREAT_COMPANY             category
# DIVERSION_COMPANY              category
# DIVERSION_METHOD               category
# DELIVERY_MODE                  category
# BOTTOM_HOLE_PRESSURE_METHOD    category
# CLOSURE_PRESSURE_METHOD        category
# STIMULATION_RESULT             category
# STIMULATION_RESULT_DETAIL      category
# FLUID_NAME                     category
# dtype: object

# %%
cat_features = pd.DataFrame(columns=qual_features.columns)
for feature in cat_features:
    cat_features[feature] = qual_features[feature].cat.codes
cat_features
# Out:
#       JOB_STATUS  LIKE_KIND  RIG_ID  RIG_TYPE  CONTRACTOR  \
# 0              0          1       2         1           2
# 1              0          3       5         1           3
# 2             -1          2       3         1           2
# 3             -1          1       5         1           3
# 4             -1          1       5         1           3
# ...          ...        ...     ...       ...         ...
# 1649          -1          1       5         1           3
# 1650          -1          1       5         1           3
# 1651          -1          1       5         1           3
# 1652          -1          1       5         1           3
# 1653          -1          1       5         1           3
#
#       STIMULATION_TREAT_TYPE  STIM_TREAT_COMPANY  DIVERSION_COMPANY  \
# 0                          3                   2                  2
# 1                          3                   3                 11
# 2                          3                   2                  0
# 3                          3                   3                  2
# 4                          3                   3                 -1
# ...                      ...                 ...                ...
# 1649                       3                   3                  2
# 1650                       3                   3                  2
# 1651                       3                   3                  2
# 1652                       3                   3                  2
# 1653                       3                   3                  2
#
#       DIVERSION_METHOD  DELIVERY_MODE  BOTTOM_HOLE_PRESSURE_METHOD  \
# 0                    8              0                           -1
# 1                   15              0                           -1
# 2                    5              0                            0
# 3                    8              0                           -1
# 4                    8              0                           -1
# ...                ...            ...                          ...
# 1649                 8              0                           -1
# 1650                 8              0                           -1
# 1651                 8              0                           -1
# 1652                 8              0                           -1
# 1653                 8              0                           -1
#
#       CLOSURE_PRESSURE_METHOD  STIMULATION_RESULT  STIMULATION_RESULT_DETAIL  \
# 0                          -1                   1                          0
# 1                          -1                   1                          0
# 2                           0                   1                          0
# 3                          -1                   1                          0
# 4                          -1                   1                          0
# ...                       ...                 ...                        ...
# 1649                       -1                   1                          0
# 1650                       -1                   1                          0
# 1651                       -1                   1                          0
# 1652                       -1                   1                          0
# 1653                       -1                   1                          0
#
#       FLUID_NAME
# 0             33
# 1             20
# 2             32
# 3             24
# 4             24
# ...          ...
# 1649          33
# 1650          33
# 1651          33
# 1652          33
# 1653          33
#
# [1654 rows x 15 columns]

# %%
g = sns.pairplot(cat_features)

# %%
chart_count = 0
for feature in cat_features:
    cur_feature = pd.Series(cat_features[feature].to_list())
    cur_counts = cur_feature.value_counts().to_frame()[0].to_list()
    plt.title(feature)
    plt.pie(cur_counts, autopct="%1.1f%%")
    plt.show()
    chart_count += 1

# %%
chart_count
# Out:
# 15

# %% [markdown]
# ## File 3

# %%
qual_features = df_3.select_dtypes(include=[np.object])
qual_features.columns
# Out:
# Index(['#WELL_NAME', 'CURRENT_STATUS', 'JOB_CATEGORY', 'JOB_START_DATE',
#        'JOB_END_DATE', 'JOB_STATUS', 'LIKE_KIND', 'PROJECT_TYPE',
#        'PHASE_START_DATE', 'PHASE_END_DATE', 'PHASE', 'JOB_OP_CODE', 'RIG_ID',
#        'RIG_ACCEPT_DATE', 'RIG_RELEASE_DATE', 'RIG_TYPE', 'CONTRACTOR',
#        'REPORT_START_DATE', 'REPORT_END_DATE', 'STIMULATION_TREAT_DATE',
#        'STIMULATION_TREAT_TYPE', 'STIM_TREAT_COMPANY', 'STIM_TREAT_SUPERVISOR',
#        'DIVERSION_COMPANY', 'DIVERSION_METHOD', 'DELIVERY_MODE',
#        'BOTTOM_HOLE_PRESSURE_METHOD', 'STIMULATION_RESULT',
#        'STIMULATION_RESULT_DETAIL', 'STG_START_DATE', 'STG_END_DATE',
#        'STIMTREAT_ID', 'FLUID_NAME', 'STIM_TREAT_REMARK', 'STG_REMARK'],
#       dtype='object')

# %%
qual_features.head()
# Out:
#           #WELL_NAME CURRENT_STATUS JOB_CATEGORY       JOB_START_DATE  \
# 0  WELL - 2019000507      Producing  COMPLETIONS  04/10/2017 00:00:00
# 1  WELL - 2019000477      Producing  COMPLETIONS  12/06/2017 07:00:00
# 2  WELL - 2019000699      Producing  COMPLETIONS  12/16/2018 06:00:00
# 3  WELL - 2019000665      Producing  COMPLETIONS  01/21/2018 10:00:00
# 4  WELL - 2019000466      Producing  COMPLETIONS  08/01/2017 06:00:00
#
#           JOB_END_DATE JOB_STATUS                   LIKE_KIND  \
# 0  04/26/2018 09:30:00  COMPLETED                OCM - PP PUC
# 1  08/06/2018 18:00:00        NaN                OCM - PP PUC
# 2  10/12/2019 10:00:00  COMPLETED  OCM - MECHANICAL ISOLATION
# 3  10/09/2018 07:00:00  COMPLETED                OCM - PP TUB
# 4                  NaN  PRODUCING                OCM - PP PUC
#
#          PROJECT_TYPE     PHASE_START_DATE       PHASE_END_DATE  ...  \
# 0  INITIAL COMPLETION  04/14/2017 17:15:00  08/19/2017 18:00:00  ...
# 1  INITIAL COMPLETION  12/11/2017 17:00:00  02/09/2018 09:00:00  ...
# 2        RECOMPLETION  01/11/2019 06:00:00  02/06/2019 07:00:00  ...
# 3        RECOMPLETION  01/27/2018 06:00:00  02/23/2018 18:00:00  ...
# 4  INITIAL COMPLETION  08/25/2017 06:00:00  10/05/2017 06:00:00  ...
#
#   DELIVERY_MODE BOTTOM_HOLE_PRESSURE_METHOD STIMULATION_RESULT  \
# 0        Casing                         NaN            Success
# 1        Casing                  Calculated            Success
# 2        Casing                         NaN            Success
# 3        Casing                         NaN            Success
# 4        Casing                         NaN            Success
#
#   STIMULATION_RESULT_DETAIL       STG_START_DATE         STG_END_DATE  \
# 0         According to Plan  07/27/2017 02:31:00  07/27/2017 04:31:00
# 1         According to Plan  01/23/2018 20:33:00  01/23/2018 21:22:00
# 2         According to Plan  01/28/2019 08:05:00  01/28/2019 10:05:00
# 3         According to Plan  02/19/2018 14:40:00  02/20/2018 00:19:00
# 4         According to Plan  09/11/2017 13:35:00  09/11/2017 15:33:00
#
#                        STIMTREAT_ID       FLUID_NAME  \
# 0  6652C6217F11405488E785A3D84CFD56         25#  XL
# 1  9808C6BE9B2746A9A63D58EEB3885939  25# GUAR BORATE
# 2  A6066AE1E85F4B1DB15D9940B5FBBEBF       Slickwater
# 3  6ACEA3AEC54E415B8251B86897A229F3      FRESH WATER
# 4  0459426A0021476CADD000E29A193E8D      Slick Water
#
#                                    STIM_TREAT_REMARK  \
# 0  STAGE 1 FRAC OPSSTART TIME: 02:31 HRS       FI...
# 1  STAGE: 1 FRAC OPERATIONSSTART TIME: 20:33 HRS ...
# 2  STAGE: 1 FRAC OPERATIONSSTART TIME:  0805 HRS ...
# 3  STAGE: 1 REFRAC OPERATIONSSTART TIME: 14:40 HR...
# 4  STAGE 1 FRAC OPSSTART TIME: 13:35 HRS       FI...
#
#                                           STG_REMARK
# 0  STAGE 1 FRAC OPSSTART TIME: 02:31 HRS       FI...
# 1  STAGE: 1 FRAC OPERATIONSSTART TIME: 20:33 HRS ...
# 2  STAGE: 1 FRAC OPERATIONSSTART TIME:  0805 HRS ...
# 3  STAGE: 1 REFRAC OPERATIONSSTART TIME: 14:40 HR...
# 4  STAGE 1 FRAC OPSSTART TIME: 13:35 HRS       FI...
#
# [5 rows x 35 columns]

# %%
for feature in qual_features:
    print("%27s: %4d" % (feature, len(qual_features[feature].unique())))
# Out:
#                  #WELL_NAME:  459
#              CURRENT_STATUS:    3
#                JOB_CATEGORY:    1
#              JOB_START_DATE:  178
#                JOB_END_DATE:  171
#                  JOB_STATUS:    4
#                   LIKE_KIND:    7
#                PROJECT_TYPE:    2
#            PHASE_START_DATE:  247
#              PHASE_END_DATE:  241
#                       PHASE:    1
#                 JOB_OP_CODE:    1
#                      RIG_ID:    7
#             RIG_ACCEPT_DATE:  311
#            RIG_RELEASE_DATE:  329
#                    RIG_TYPE:    5
#                  CONTRACTOR:    5
#           REPORT_START_DATE:  999
#             REPORT_END_DATE: 1055
#      STIMULATION_TREAT_DATE: 17433
#      STIMULATION_TREAT_TYPE:    6
#          STIM_TREAT_COMPANY:    6
#       STIM_TREAT_SUPERVISOR:   88
#           DIVERSION_COMPANY:   26
#            DIVERSION_METHOD:   25
#               DELIVERY_MODE:    4
# BOTTOM_HOLE_PRESSURE_METHOD:    2
#          STIMULATION_RESULT:    7
#   STIMULATION_RESULT_DETAIL:   21
#              STG_START_DATE: 17433
#                STG_END_DATE: 17465
#                STIMTREAT_ID: 17720
#                  FLUID_NAME:   79
#           STIM_TREAT_REMARK: 17548
#                  STG_REMARK: 17548

# %%
# Getting rid of dates as these will be handled 
# differently from other qualitative features
cur_features = [feature for feature in qual_features if not "DATE" in feature]
cur_features
# Out:
# ['#WELL_NAME',
#  'CURRENT_STATUS',
#  'JOB_CATEGORY',
#  'JOB_STATUS',
#  'LIKE_KIND',
#  'PROJECT_TYPE',
#  'PHASE',
#  'JOB_OP_CODE',
#  'RIG_ID',
#  'RIG_TYPE',
#  'CONTRACTOR',
#  'STIMULATION_TREAT_TYPE',
#  'STIM_TREAT_COMPANY',
#  'STIM_TREAT_SUPERVISOR',
#  'DIVERSION_COMPANY',
#  'DIVERSION_METHOD',
#  'DELIVERY_MODE',
#  'BOTTOM_HOLE_PRESSURE_METHOD',
#  'STIMULATION_RESULT',
#  'STIMULATION_RESULT_DETAIL',
#  'STIMTREAT_ID',
#  'FLUID_NAME',
#  'STIM_TREAT_REMARK',
#  'STG_REMARK']

# %%
qual_features = df_2[cur_features]

# %%
for feature in qual_features:
    print("%27s: %4d" % (feature, len(qual_features[feature].unique())))
# Out:
#                  #WELL_NAME:   67
#              CURRENT_STATUS:    1
#                JOB_CATEGORY:    1
#                  JOB_STATUS:    3
#                   LIKE_KIND:    5
#                PROJECT_TYPE:    1
#                       PHASE:    1
#                 JOB_OP_CODE:    1
#                      RIG_ID:    7
#                    RIG_TYPE:    2
#                  CONTRACTOR:    5
#      STIMULATION_TREAT_TYPE:    4
#          STIM_TREAT_COMPANY:    6
#       STIM_TREAT_SUPERVISOR:   28
#           DIVERSION_COMPANY:   13
#            DIVERSION_METHOD:   20
#               DELIVERY_MODE:    3
# BOTTOM_HOLE_PRESSURE_METHOD:    2
#          STIMULATION_RESULT:    3
#   STIMULATION_RESULT_DETAIL:    4
#                STIMTREAT_ID: 1654
#                  FLUID_NAME:   40
#           STIM_TREAT_REMARK: 1654
#                  STG_REMARK: 1654

# %%
# If a qualitative feature only has 1 unique element, then delete
single_element = [feature for feature in qual_features if len(qual_features[feature].unique()) != 1]
single_element
# Out:
# ['#WELL_NAME',
#  'JOB_STATUS',
#  'LIKE_KIND',
#  'RIG_ID',
#  'RIG_TYPE',
#  'CONTRACTOR',
#  'STIMULATION_TREAT_TYPE',
#  'STIM_TREAT_COMPANY',
#  'STIM_TREAT_SUPERVISOR',
#  'DIVERSION_COMPANY',
#  'DIVERSION_METHOD',
#  'DELIVERY_MODE',
#  'BOTTOM_HOLE_PRESSURE_METHOD',
#  'STIMULATION_RESULT',
#  'STIMULATION_RESULT_DETAIL',
#  'STIMTREAT_ID',
#  'FLUID_NAME',
#  'STIM_TREAT_REMARK',
#  'STG_REMARK']

# %%
qual_features = df_2[single_element]
qual_features
# Out:
#              #WELL_NAME JOB_STATUS                   LIKE_KIND  \
# 0     WELL - 2019000699  COMPLETED  OCM - MECHANICAL ISOLATION
# 1     WELL - 2019000665  COMPLETED                OCM - PP TUB
# 2     WELL - 2019000347        NaN                OCM - PP PUC
# 3     WELL - 2019001412        NaN  OCM - MECHANICAL ISOLATION
# 4     WELL - 2019001390        NaN  OCM - MECHANICAL ISOLATION
# ...                 ...        ...                         ...
# 1649  WELL - 2019000628        NaN  OCM - MECHANICAL ISOLATION
# 1650  WELL - 2019000628        NaN  OCM - MECHANICAL ISOLATION
# 1651  WELL - 2019000628        NaN  OCM - MECHANICAL ISOLATION
# 1652  WELL - 2019000628        NaN  OCM - MECHANICAL ISOLATION
# 1653  WELL - 2019000628        NaN  OCM - MECHANICAL ISOLATION
#
#                    RIG_ID    RIG_TYPE               CONTRACTOR  \
# 0     RIG_ID - 2019000082  FRAC EQUIP  CONTRACTOR - 2019000027
# 1     RIG_ID - 2019000098  FRAC EQUIP  CONTRACTOR - 2019000030
# 2     RIG_ID - 2019000084  FRAC EQUIP  CONTRACTOR - 2019000027
# 3     RIG_ID - 2019000098  FRAC EQUIP  CONTRACTOR - 2019000030
# 4     RIG_ID - 2019000098  FRAC EQUIP  CONTRACTOR - 2019000030
# ...                   ...         ...                      ...
# 1649  RIG_ID - 2019000098  FRAC EQUIP  CONTRACTOR - 2019000030
# 1650  RIG_ID - 2019000098  FRAC EQUIP  CONTRACTOR - 2019000030
# 1651  RIG_ID - 2019000098  FRAC EQUIP  CONTRACTOR - 2019000030
# 1652  RIG_ID - 2019000098  FRAC EQUIP  CONTRACTOR - 2019000030
# 1653  RIG_ID - 2019000098  FRAC EQUIP  CONTRACTOR - 2019000030
#
#      STIMULATION_TREAT_TYPE               STIM_TREAT_COMPANY  \
# 0        Hydraulic Fracture  STIM_TREAT_COMPANY - 2019000004
# 1        Hydraulic Fracture  STIM_TREAT_COMPANY - 2019000005
# 2        Hydraulic Fracture  STIM_TREAT_COMPANY - 2019000004
# 3        Hydraulic Fracture  STIM_TREAT_COMPANY - 2019000005
# 4        Hydraulic Fracture  STIM_TREAT_COMPANY - 2019000005
# ...                     ...                              ...
# 1649     Hydraulic Fracture  STIM_TREAT_COMPANY - 2019000005
# 1650     Hydraulic Fracture  STIM_TREAT_COMPANY - 2019000005
# 1651     Hydraulic Fracture  STIM_TREAT_COMPANY - 2019000005
# 1652     Hydraulic Fracture  STIM_TREAT_COMPANY - 2019000005
# 1653     Hydraulic Fracture  STIM_TREAT_COMPANY - 2019000005
#
#      STIM_TREAT_SUPERVISOR               DIVERSION_COMPANY  DIVERSION_METHOD  \
# 0                      NaN  DIVERSION_COMPANY - 2019000007         Frac Plug
# 1                     JEFF  DIVERSION_COMPANY - 2019000037      SILICA FLOUR
# 2                   STG 27  DIVERSION_COMPANY - 2019000003  Ball 40  7/8 BIO
# 3                      NaN  DIVERSION_COMPANY - 2019000007         Frac Plug
# 4                      NaN                             NaN         Frac Plug
# ...                    ...                             ...               ...
# 1649                   NaN  DIVERSION_COMPANY - 2019000007         Frac Plug
# 1650                   NaN  DIVERSION_COMPANY - 2019000007         Frac Plug
# 1651                   NaN  DIVERSION_COMPANY - 2019000007         Frac Plug
# 1652                   NaN  DIVERSION_COMPANY - 2019000007         Frac Plug
# 1653                   NaN  DIVERSION_COMPANY - 2019000007         Frac Plug
#
#      DELIVERY_MODE BOTTOM_HOLE_PRESSURE_METHOD STIMULATION_RESULT  \
# 0           Casing                         NaN            Success
# 1           Casing                         NaN            Success
# 2           Casing                  Calculated            Success
# 3           Casing                         NaN            Success
# 4           Casing                         NaN            Success
# ...            ...                         ...                ...
# 1649        Casing                         NaN            Success
# 1650        Casing                         NaN            Success
# 1651        Casing                         NaN            Success
# 1652        Casing                         NaN            Success
# 1653        Casing                         NaN            Success
#
#      STIMULATION_RESULT_DETAIL                      STIMTREAT_ID   FLUID_NAME  \
# 0            According to Plan  A6066AE1E85F4B1DB15D9940B5FBBEBF   Slickwater
# 1            According to Plan  6ACEA3AEC54E415B8251B86897A229F3  FRESH WATER
# 2            According to Plan  29626CB5494D45ACB9C7723B028E9DEF  Slick Water
# 3            According to Plan  DCCB82735EEA4540A1C0C402180C5A45       FRP-1S
# 4            According to Plan  B8733A01BFFD46CC8CCDE726BD4B484B       FRP-1S
# ...                        ...                               ...          ...
# 1649         According to Plan  3378EA55ECFB4D998B852424A305E2BF   Slickwater
# 1650         According to Plan  D59E4DC0E1654C11B392325DACBEBD11   Slickwater
# 1651         According to Plan  4BC64FC4AF8E463989399F926EFD55D2   Slickwater
# 1652         According to Plan  C464F9B9992947379161C633C1822EA9   Slickwater
# 1653         According to Plan  0FC2C86779A146D19DA60CFA5075FE4A   Slickwater
#
#                                       STIM_TREAT_REMARK  \
# 0     STAGE: 1 FRAC OPERATIONSSTART TIME:  0805 HRS ...
# 1     STAGE: 1 REFRAC OPERATIONSSTART TIME: 14:40 HR...
# 2     STAGE: 2 FRAC OPSTART TIME: 10:13 HRS       FI...
# 3     STAGE: 1 FRAC OPERATIONSSTART TIME:  14:05 HRS...
# 4     STAGE: 27  RE-FRAC OPERATIONSSTART TIME:  07:1...
# ...                                                 ...
# 1649  STAGE: 50 FRAC OPERATIONSSTART TIME: 15:26 HRS...
# 1650  STAGE: 51 FRAC OPERATIONSSTART TIME: 18:21 HRS...
# 1651  STAGE: 52 FRAC OPERATIONSSTART TIME: 21:27 HRS...
# 1652  STAGE: 53 FRAC OPERATIONSSTART TIME: 00:30 HRS...
# 1653  STAGE: 54 FRAC OPERATIONSSTART TIME: 03:35 HRS...
#
#                                              STG_REMARK
# 0     STAGE: 1 FRAC OPERATIONSSTART TIME:  0805 HRS ...
# 1     STAGE: 1 REFRAC OPERATIONSSTART TIME: 14:40 HR...
# 2     STAGE: 2 FRAC OPSTART TIME: 10:13 HRS       FI...
# 3     STAGE: 1 FRAC OPERATIONSSTART TIME:  14:05 HRS...
# 4     STAGE: 27  RE-FRAC OPERATIONSSTART TIME:  07:1...
# ...                                                 ...
# 1649  STAGE: 50 FRAC OPERATIONSSTART TIME: 15:26 HRS...
# 1650  STAGE: 51 FRAC OPERATIONSSTART TIME: 18:21 HRS...
# 1651  STAGE: 52 FRAC OPERATIONSSTART TIME: 21:27 HRS...
# 1652  STAGE: 53 FRAC OPERATIONSSTART TIME: 00:30 HRS...
# 1653  STAGE: 54 FRAC OPERATIONSSTART TIME: 03:35 HRS...
#
# [1654 rows x 19 columns]

# %%
for feature in qual_features:
    print("%27s: %4d" % (feature, len(qual_features[feature].unique())))
# Out:
#                  #WELL_NAME:   67
#                  JOB_STATUS:    3
#                   LIKE_KIND:    5
#                      RIG_ID:    7
#                    RIG_TYPE:    2
#                  CONTRACTOR:    5
#      STIMULATION_TREAT_TYPE:    4
#          STIM_TREAT_COMPANY:    6
#       STIM_TREAT_SUPERVISOR:   28
#           DIVERSION_COMPANY:   13
#            DIVERSION_METHOD:   20
#               DELIVERY_MODE:    3
# BOTTOM_HOLE_PRESSURE_METHOD:    2
#          STIMULATION_RESULT:    3
#   STIMULATION_RESULT_DETAIL:    4
#                STIMTREAT_ID: 1654
#                  FLUID_NAME:   40
#           STIM_TREAT_REMARK: 1654
#                  STG_REMARK: 1654

# %%
to_remove = [
    "#WELL_NAME",
    "STIM_TREAT_SUPERVISOR",
    "STIMTREAT_ID",
    "STIM_TREAT_REMARK",
    "STG_REMARK"
]

qual_features = qual_features.drop(columns = to_remove)

# %%
for feature in qual_features:
    print("%27s: %4d" % (feature, len(qual_features[feature].unique())))
# Out:
#                  JOB_STATUS:    3
#                   LIKE_KIND:    5
#                      RIG_ID:    7
#                    RIG_TYPE:    2
#                  CONTRACTOR:    5
#      STIMULATION_TREAT_TYPE:    4
#          STIM_TREAT_COMPANY:    6
#           DIVERSION_COMPANY:   13
#            DIVERSION_METHOD:   20
#               DELIVERY_MODE:    3
# BOTTOM_HOLE_PRESSURE_METHOD:    2
#          STIMULATION_RESULT:    3
#   STIMULATION_RESULT_DETAIL:    4
#                  FLUID_NAME:   40

# %%
qual_features.columns
# Out:
# Index(['JOB_STATUS', 'LIKE_KIND', 'RIG_ID', 'RIG_TYPE', 'CONTRACTOR',
#        'STIMULATION_TREAT_TYPE', 'STIM_TREAT_COMPANY', 'DIVERSION_COMPANY',
#        'DIVERSION_METHOD', 'DELIVERY_MODE', 'BOTTOM_HOLE_PRESSURE_METHOD',
#        'STIMULATION_RESULT', 'STIMULATION_RESULT_DETAIL', 'FLUID_NAME'],
#       dtype='object')

# %%
for feature in qual_features.columns:
    qual_features[feature] = qual_features[feature].astype('category')

# %%
qual_features.dtypes
# Out:
# JOB_STATUS                     category
# LIKE_KIND                      category
# RIG_ID                         category
# RIG_TYPE                       category
# CONTRACTOR                     category
# STIMULATION_TREAT_TYPE         category
# STIM_TREAT_COMPANY             category
# DIVERSION_COMPANY              category
# DIVERSION_METHOD               category
# DELIVERY_MODE                  category
# BOTTOM_HOLE_PRESSURE_METHOD    category
# STIMULATION_RESULT             category
# STIMULATION_RESULT_DETAIL      category
# FLUID_NAME                     category
# dtype: object

# %%
cat_features = pd.DataFrame(columns=qual_features.columns)
for feature in cat_features:
    cat_features[feature] = qual_features[feature].cat.codes
cat_features
# Out:
#       JOB_STATUS  LIKE_KIND  RIG_ID  RIG_TYPE  CONTRACTOR  \
# 0              0          1       2         1           2
# 1              0          3       5         1           3
# 2             -1          2       3         1           2
# 3             -1          1       5         1           3
# 4             -1          1       5         1           3
# ...          ...        ...     ...       ...         ...
# 1649          -1          1       5         1           3
# 1650          -1          1       5         1           3
# 1651          -1          1       5         1           3
# 1652          -1          1       5         1           3
# 1653          -1          1       5         1           3
#
#       STIMULATION_TREAT_TYPE  STIM_TREAT_COMPANY  DIVERSION_COMPANY  \
# 0                          3                   2                  2
# 1                          3                   3                 11
# 2                          3                   2                  0
# 3                          3                   3                  2
# 4                          3                   3                 -1
# ...                      ...                 ...                ...
# 1649                       3                   3                  2
# 1650                       3                   3                  2
# 1651                       3                   3                  2
# 1652                       3                   3                  2
# 1653                       3                   3                  2
#
#       DIVERSION_METHOD  DELIVERY_MODE  BOTTOM_HOLE_PRESSURE_METHOD  \
# 0                    8              0                           -1
# 1                   15              0                           -1
# 2                    5              0                            0
# 3                    8              0                           -1
# 4                    8              0                           -1
# ...                ...            ...                          ...
# 1649                 8              0                           -1
# 1650                 8              0                           -1
# 1651                 8              0                           -1
# 1652                 8              0                           -1
# 1653                 8              0                           -1
#
#       STIMULATION_RESULT  STIMULATION_RESULT_DETAIL  FLUID_NAME
# 0                      1                          0          33
# 1                      1                          0          20
# 2                      1                          0          32
# 3                      1                          0          24
# 4                      1                          0          24
# ...                  ...                        ...         ...
# 1649                   1                          0          33
# 1650                   1                          0          33
# 1651                   1                          0          33
# 1652                   1                          0          33
# 1653                   1                          0          33
#
# [1654 rows x 14 columns]

# %%
g = sns.pairplot(cat_features)

# %%
chart_count = 0
for feature in cat_features:
    cur_feature = pd.Series(cat_features[feature].to_list())
    cur_counts = cur_feature.value_counts().to_frame()[0].to_list()
    plt.title(feature)
    plt.pie(cur_counts)
    plt.show()
    chart_count += 1

# %%
chart_count
